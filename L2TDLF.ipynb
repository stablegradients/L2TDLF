# %%
import copy
import numpy as np
import os
import torch
import torch.nn as nn
import torch.utils.data as utils
import torch.nn.functional as F
import higher
import pickle
from torchvision import datasets, transforms
import argparse
import tqdm

from dataloaders import get_data
from models import *
from sklearn.metrics import accuracy_score, precision_score

# %% [markdown]
# ## The student model

# %% [markdown]
# Here we define the student model to be used to train on cifar-10 dataset. <br />
# The output is the 10 dimensional softmax output

# %%
import torch.nn as nn
import torch.nn.functional as F


class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(1, 10, kernel_size=5)
        self.conv2 = nn.Conv2d(10, 20, kernel_size=5)
        self.conv2_drop = nn.Dropout2d()
        self.fc1 = nn.Linear(320, 50)
        self.fc2 = nn.Linear(50, 10)

    def forward(self, x):
        x = F.leaky_relu(F.max_pool2d(self.conv1(x), 2), negative_slope=0.1)
        x = F.leaky_relu(F.max_pool2d(self.conv2_drop(self.conv2(x)), 2), negative_slope=0.1)
        x = x.view(-1, 320)
        x = F.leaky_relu(self.fc1(x), negative_slope=0.1)
        x = F.dropout(x, training=self.training)
        x = self.fc2(x)
        return F.softmax(x, dim=1)

sample_student = Net()
preds = sample_student(torch.randn((1,1, 28,28)))
print(torch.sum(preds))
del sample_student
del preds
# Out:
# tensor(1.0000, grad_fn=<SumBackward0>)

# %% [markdown]
# ## Teacher Model

# %% [markdown]
# We define the teacher model which calculates the weighted cross entropy loss on <br />

# %%
class Teacher(nn.Module):
    def __init__(self, classes=10, st_dim=13, hidden_dim=16):
        super(Teacher, self).__init__()
        self.V = torch.nn.Parameter(torch.randn(hidden_dim,st_dim))
        self.V.requires_grad = True
        self.W = torch.nn.Parameter(torch.randn(classes,classes,hidden_dim))
        self.W.requires_grad = True
        self.phi = torch.nn.Parameter(0.1 * torch.randn(classes,classes) + torch.eye(classes))
        self.phi.requires_grad = True
        self.softmax = nn.Softmax()
        self.sigmoid = nn.Sigmoid()
    def forward(self, st, pw, y):
        '''
        W_channel_weights = self.softmax(torch.matmul(st, self.V.T))
        phi = torch.matmul(self.W, W_channel_weights)
        logpw_weights = torch.matmul(y, phi)
        loss = torch.mean(-1 * self.sigmoid(logpw_weights*torch.log(pw)))
        '''
        loss = torch.mean(-1 * self.sigmoid(torch.matmul(y, self.phi) * torch.log(pw)))
        
        return loss

# %%
def get_loss(student, teacher, x, y, state=None, val=False):
    if val:
        # this is the loss function that the teacher tries to minimize
        return  -1 * torch.mean(torch.sum(y * student(x), dim=1))
    else:
        # this is the loss function given by the teacher to optimize the student 
        # in the inner meta loop
        preds = student(x)
        student_loss = teacher(state, preds, y)
        return student_loss

# %%
teacher = Teacher()
student = Net()

st = torch.randn((13)).float()
sample_input = torch.randn((5, 1, 28,28))
pw = student(sample_input)
y = F.one_hot(torch.randint(0, 10, (5,)), num_classes=10).float()

result = teacher(st, pw, y)
#result.backward()
loss = get_loss(student, teacher, sample_input, y , st, val=False)
loss.backward()
# print( "V mean grad", torch.mean(torch.abs(teacher.V.grad)), "V max grad", torch.max(torch.abs(teacher.V.grad)) )
print("phi mean grad", torch.mean(torch.abs(teacher.phi.grad)), "V max grad", torch.max(torch.abs(teacher.phi.grad)) )
print(get_loss(student, teacher, sample_input, y , st, val=True))

del student
del teacher
# Out:
# phi mean grad tensor(0.0053) V max grad tensor(0.0139)
# tensor(-0.0966, grad_fn=<MulBackward0>)

# %%
def get_metrics(student, train_dl, val_dl):
    train_preds = []
    train_gt = []
    val_preds = []
    val_gt = []
    # running the loop for training dataset
    for i, (x,y) in enumerate(train_dl):
        y_pred = torch.max(F.softmax(student(x), dim=1), 1)[1]
        train_preds.append(y_pred)
        train_gt.append(y)

    # running the loop for validation dataset
    for i, (x,y) in enumerate(val_dl):
        y_pred = torch.max(F.softmax(student(x), dim=1), 1)[1]
        val_preds.append(y_pred)
        val_gt.append(y)

    train_preds = torch.cat(train_preds, dim=0).detach().numpy()
    train_gt = torch.cat(train_gt, dim=0).detach().numpy()
    val_preds = torch.cat(val_preds, dim=0).detach().numpy()
    val_gt = torch.cat(val_gt, dim=0).detach().numpy()

    train_acc = accuracy_score(train_gt, train_preds, normalize=True)
    val_acc = accuracy_score(val_gt, val_preds, normalize=True)
    prescision = precision_score(val_gt, val_preds, average=None)
    return torch.cat([torch.tensor([train_acc]), torch.tensor([val_acc]), torch.tensor(prescision)],0)

# %%
train_loader, val_loader, test_loader = get_data(dataset="mnist")

# %%
def do_train_student(student, optimizer, teacher, train_dl, val_dl, iter=0,inner_steps=100):
    student.train()
    teacher.train()
    metrics = None# get_metrics(student, train_dl, val_dl).float()

    for i, (x,y) in enumerate(train_dl):
        x = x.float()
        y = F.one_hot(y, num_classes=10).float()

        # try to get the state vector here
        state = None # torch.cat([torch.tensor([float(iter/20.0)]), metrics])

        student_loss = get_loss(student, teacher, x, y, state=state, val=False)
        loss = student_loss
        if torch.isnan(student_loss):
            if torch.sum(student(x) <= 0):
                print("non positive value inside log found hence nan loss")
            print("=" * 30)
        # higher library exposes this interface for zero_grad on optimizer, loss.backward(), and optim.step()
        else:
            optimizer.step(loss)

        print('Train student: Step ', i, "loss value is", student_loss)
        if i>100:
            break
    return student

# %%
def do_train_teacher(teacher, optimizer, student, train_dl):
    lossdict = {
        'teach_loss' : [],
    }

    student.train()
    teacher.train()
    netloss = None
    for i, (x,y) in enumerate(train_dl):
        x = x.float()
        y = F.one_hot(y, num_classes=10).float()
        # Set val=True to get unweighted loss
        teacher_loss = get_loss(student, teacher, x, y, i, val=True)

        # Teacher is trained to minimise the student's classification error loss after training
        if netloss is None:
            netloss = teacher_loss
        else:
            netloss += teacher_loss

        print('Train Teacher: Step ', i, "  Teacher loss this step is:", teacher_loss)
        if i>50:
            break

    # Accumulate losses and do the step after we process outer_steps number of batches.
    netloss = netloss/(i+1)
    netloss.backward(retain_graph=True)
    return lossdict, teacher

# %%
def train(train_dl, val_dl, test_dl, num_steps):
    student = Net()
    teacher = Teacher()

    teacher_optim = torch.optim.Adam(teacher.parameters(), lr=1e-2)

    stud_state_dict = copy.deepcopy(student.state_dict())

    for ep in range(num_steps):
        student.load_state_dict(stud_state_dict, strict=True)
        stud_optim = torch.optim.Adam(student.parameters(), lr=1e-4)

        teacher_optim.zero_grad()
        print("inside epoch before higher optim")
        # The outer loop optimiser (teacher optimiser) does not change the student params, so copy_initial_weights can be True or False
        with higher.innerloop_ctx(student, stud_optim, copy_initial_weights=False) as (fnet, diffopt):
            fnet = do_train_student(fnet, diffopt, teacher, train_dl, val_dl)
            # Note: do_train_student does not edit the .grad field of teacher parameters
            # Therefore, no need to clear teacher grads before do_train_teacher.
            teacher_ld, teacher = do_train_teacher(teacher, teacher_optim, fnet, val_dl)
            student.load_state_dict(fnet.state_dict())
            # print( "V mean grad", torch.mean(torch.abs(teacher.V.grad)), "V max grad", torch.max(torch.abs(teacher.V.grad)) )
            print("phi mean grad", torch.mean(torch.abs(teacher.phi.grad)), "V max grad", torch.max(torch.abs(teacher.phi.grad)) )

            grad = student.conv1.weight.grad
            print( "student conv1 mean grad", torch.mean(torch.abs(grad)), "student conv1 max grad", torch.max(torch.abs(grad)) )

        teacher_optim.step()
        print(teacher.phi)

        #stud_train_ld = update_lossdict(stud_train_ld, student_ld)
        #teacher_train_ld = update_lossdict(teacher_train_ld, teacher_ld)

        print("Teacher training step: ", ep)

        #tld = eval_student(student, test_dl)
        #stud_test_ld = update_lossdict(stud_test_ld, tld)
        #vld = eval_student(student, val_dl)
        #stud_val_ld = update_lossdict(stud_val_ld, vld)

        #train_ep = eval_student(student, train_dl)
        #stud_train_ld = update_lossdict(stud_train_ld, train_ep) 

    return teacher, student

# %%
teacher, student = train(train_loader, val_loader, test_loader, num_steps=1000)
# Out:
# inside epoch before higher optim
# Train student: Step  0 loss value is tensor(-0.4621, grad_fn=<MeanBackward0>)
# Train student: Step  1 loss value is tensor(-0.4624, grad_fn=<MeanBackward0>)
# Train student: Step  2 loss value is tensor(-0.4644, grad_fn=<MeanBackward0>)
# Train student: Step  3 loss value is tensor(-0.4629, grad_fn=<MeanBackward0>)
# Train student: Step  4 loss value is tensor(-0.4674, grad_fn=<MeanBackward0>)
# Train student: Step  5 loss value is tensor(-0.4567, grad_fn=<MeanBackward0>)
# Train student: Step  6 loss value is tensor(-0.4594, grad_fn=<MeanBackward0>)
# Train student: Step  7 loss value is tensor(-0.4676, grad_fn=<MeanBackward0>)
# Train student: Step  8 loss value is tensor(-0.4637, grad_fn=<MeanBackward0>)
# Train student: Step  9 loss value is tensor(-0.4643, grad_fn=<MeanBackward0>)
# Train student: Step  10 loss value is tensor(-0.4618, grad_fn=<MeanBackward0>)
# Train student: Step  11 loss value is tensor(-0.4603, grad_fn=<MeanBackward0>)
# Train student: Step  12 loss value is tensor(-0.4609, grad_fn=<MeanBackward0>)
# Train student: Step  13 loss value is tensor(-0.4661, grad_fn=<MeanBackward0>)
# Train student: Step  14 loss value is tensor(-0.4650, grad_fn=<MeanBackward0>)
# Train student: Step  15 loss value is tensor(-0.4594, grad_fn=<MeanBackward0>)
# Train student: Step  16 loss value is tensor(-0.4643, grad_fn=<MeanBackward0>)
# Train student: Step  17 loss value is tensor(-0.4608, grad_fn=<MeanBackward0>)
# Train student: Step  18 loss value is tensor(-0.4602, grad_fn=<MeanBackward0>)
# Train student: Step  19 loss value is tensor(-0.4621, grad_fn=<MeanBackward0>)
# Train student: Step  20 loss value is tensor(-0.4672, grad_fn=<MeanBackward0>)
# Train student: Step  21 loss value is tensor(-0.4640, grad_fn=<MeanBackward0>)
# Train student: Step  22 loss value is tensor(-0.4622, grad_fn=<MeanBackward0>)
# Train student: Step  23 loss value is tensor(-0.4646, grad_fn=<MeanBackward0>)
# Train student: Step  24 loss value is tensor(-0.4595, grad_fn=<MeanBackward0>)
# Train student: Step  100 loss value is tensor(-0.4756, grad_fn=<MeanBackward0>)
# Train student: Step  101 loss value is tensor(-0.4745, grad_fn=<MeanBackward0>)
# Train Teacher: Step  0   Teacher loss this step is: tensor(-0.1157, grad_fn=<MulBackward0>)
# Train Teacher: Step  1   Teacher loss this step is: tensor(-0.1116, grad_fn=<MulBackward0>)
# Train Teacher: Step  2   Teacher loss this step is: tensor(-0.1256, grad_fn=<MulBackward0>)
# Train Teacher: Step  3   Teacher loss this step is: tensor(-0.0904, grad_fn=<MulBackward0>)
# Train Teacher: Step  4   Teacher loss this step is: tensor(-0.0957, grad_fn=<MulBackward0>)
# Train Teacher: Step  5   Teacher loss this step is: tensor(-0.1378, grad_fn=<MulBackward0>)
# Train Teacher: Step  6   Teacher loss this step is: tensor(-0.0981, grad_fn=<MulBackward0>)
# Train Teacher: Step  7   Teacher loss this step is: tensor(-0.1248, grad_fn=<MulBackward0>)
# Train Teacher: Step  8   Teacher loss this step is: tensor(-0.1319, grad_fn=<MulBackward0>)
# Train Teacher: Step  9   Teacher loss this step is: tensor(-0.0800, grad_fn=<MulBackward0>)
# Train Teacher: Step  10   Teacher loss this step is: tensor(-0.1339, grad_fn=<MulBackward0>)
# Train Teacher: Step  11   Teacher loss this step is: tensor(-0.0862, grad_fn=<MulBackward0>)
# Train Teacher: Step  12   Teacher loss this step is: tensor(-0.1224, grad_fn=<MulBackward0>)
# Train Teacher: Step  13   Teacher loss this step is: tensor(-0.0580, grad_fn=<MulBackward0>)
# Train Teacher: Step  14   Teacher loss this step is: tensor(-0.1166, grad_fn=<MulBackward0>)
# Train Teacher: Step  15   Teacher loss this step is: tensor(-0.1348, grad_fn=<MulBackward0>)
# Train Teacher: Step  16   Teacher loss this step is: tensor(-0.1345, grad_fn=<MulBackward0>)
# Train Teacher: Step  17   Teacher loss this step is: tensor(-0.1131, grad_fn=<MulBackward0>)
# Train Teacher: Step  18   Teacher loss this step is: tensor(-0.0932, grad_fn=<MulBackward0>)
# Train Teacher: Step  19   Teacher loss this step is: tensor(-0.1008, grad_fn=<MulBackward0>)
# Train Teacher: Step  20   Teacher loss this step is: tensor(-0.1392, grad_fn=<MulBackward0>)
# Train Teacher: Step  21   Teacher loss this step is: tensor(-0.0823, grad_fn=<MulBackward0>)
# Train Teacher: Step  22   Teacher loss this step is: tensor(-0.1153, grad_fn=<MulBackward0>)
# Train Teacher: Step  23   Teacher loss this step is: tensor(-0.1453, grad_fn=<MulBackward0>)
# Train Teacher: Step  24   Teacher loss this step is: tensor(-0.1420, grad_fn=<MulBackward0>)
# Train Teacher: Step  25   Teacher loss this step is: tensor(-0.0935, grad_fn=<MulBackward0>)
# Train Teacher: Step  26   Teacher loss this step is: tensor(-0.0967, grad_fn=<MulBackward0>)
# Train Teacher: Step  27   Teacher loss this step is: tensor(-0.1289, grad_fn=<MulBackward0>)
# Train Teacher: Step  28   Teacher loss this step is: tensor(-0.1251, grad_fn=<MulBackward0>)
# Train Teacher: Step  29   Teacher loss this step is: tensor(-0.1286, grad_fn=<MulBackward0>)
# Train Teacher: Step  30   Teacher loss this step is: tensor(-0.1427, grad_fn=<MulBackward0>)
# Train Teacher: Step  31   Teacher loss this step is: tensor(-0.1262, grad_fn=<MulBackward0>)
# Train Teacher: Step  32   Teacher loss this step is: tensor(-0.1225, grad_fn=<MulBackward0>)
# Train Teacher: Step  33   Teacher loss this step is: tensor(-0.1178, grad_fn=<MulBackward0>)
# Train Teacher: Step  34   Teacher loss this step is: tensor(-0.1070, grad_fn=<MulBackward0>)
# Train Teacher: Step  35   Teacher loss this step is: tensor(-0.1217, grad_fn=<MulBackward0>)
# Train Teacher: Step  36   Teacher loss this step is: tensor(-0.1326, grad_fn=<MulBackward0>)
# Train Teacher: Step  37   Teacher loss this step is: tensor(-0.1290, grad_fn=<MulBackward0>)
# Train Teacher: Step  38   Teacher loss this step is: tensor(-0.0778, grad_fn=<MulBackward0>)
# Train Teacher: Step  39   Teacher loss this step is: tensor(-0.1061, grad_fn=<MulBackward0>)
# Train Teacher: Step  40   Teacher loss this step is: tensor(-0.1174, grad_fn=<MulBackward0>)
# Train Teacher: Step  41   Teacher loss this step is: tensor(-0.0901, grad_fn=<MulBackward0>)
# Train Teacher: Step  42   Teacher loss this step is: tensor(-0.0898, grad_fn=<MulBackward0>)
# Train Teacher: Step  43   Teacher loss this step is: tensor(-0.1187, grad_fn=<MulBackward0>)
# Train Teacher: Step  44   Teacher loss this step is: tensor(-0.1278, grad_fn=<MulBackward0>)
# Train Teacher: Step  45   Teacher loss this step is: tensor(-0.0937, grad_fn=<MulBackward0>)
# Train Teacher: Step  46   Teacher loss this step is: tensor(-0.1421, grad_fn=<MulBackward0>)
# Train Teacher: Step  47   Teacher loss this step is: tensor(-0.1260, grad_fn=<MulBackward0>)
# Train Teacher: Step  48   Teacher loss this step is: tensor(-0.1141, grad_fn=<MulBackward0>)
# Train Teacher: Step  49   Teacher loss this step is: tensor(-0.1122, grad_fn=<MulBackward0>)
# Train Teacher: Step  50   Teacher loss this step is: tensor(-0.1013, grad_fn=<MulBackward0>)
# Train Teacher: Step  51   Teacher loss this step is: tensor(-0.1193, grad_fn=<MulBackward0>)
# phi mean grad tensor(0.0079) V max grad tensor(0.0189)
# student conv1 mean grad tensor(0.0018) student conv1 max grad tensor(0.0065)
# test
# Parameter containing:
# tensor([[ 7.7461e-01,  6.8272e-03, -6.2751e-03, -1.0704e-01,  5.1379e-02,
#          -3.3048e-02,  9.3142e-02, -8.8711e-02, -5.9932e-02, -1.4189e-01],
#         [-2.5935e-02,  1.0127e+00, -1.0453e-01, -1.3236e-01, -9.8136e-02,
#          -1.4297e-01,  2.4461e-02, -1.0012e-02, -8.3843e-02,  1.8064e-02],
#         [-6.6846e-02,  8.0044e-02,  9.9281e-01, -9.1564e-02, -4.7224e-02,
#          -6.2363e-02, -1.2750e-01, -1.3635e-01,  1.9283e-01, -1.3773e-01],
#         [-8.3719e-02,  4.6629e-02,  9.9728e-04,  7.1431e-01,  1.2158e-01,
#           1.5325e-01, -2.2152e-02,  2.0185e-01,  1.0646e-01,  1.2000e-02],
#         [ 1.7972e-02, -1.0084e-01,  7.2285e-02, -9.9368e-02,  1.1354e+00,
#           2.0053e-02,  1.7660e-01, -1.0700e-01, -1.4572e-02,  1.5397e-01],
#         [ 1.2074e-01, -3.6114e-02,  1.1766e-01,  1.9004e-01, -3.1035e-02,
#           1.0538e+00,  5.4607e-02,  1.7094e-01, -3.1917e-01,  9.6169e-02],
#         [ 1.6548e-01,  8.4689e-02, -2.1195e-02,  1.7056e-01,  6.4424e-02,
#           2.3518e-01,  9.2036e-01, -1.6873e-03, -8.9359e-02, -5.5078e-02],
#         [-9.0060e-02,  7.9946e-02,  1.1316e-01, -6.3638e-02,  8.5884e-02,
#          -6.3161e-02, -5.3005e-02,  9.3612e-01, -2.1660e-01, -4.3457e-02],
#         [ 1.1134e-01, -3.8619e-02, -3.4606e-02,  2.6233e-02,  3.8537e-02,
#           3.0046e-02,  1.1519e-01,  6.1813e-02,  9.7540e-01, -8.7541e-02],
#         [-1.7647e-01, -6.9246e-02, -7.5956e-03, -2.2596e-02,  1.4573e-01,
#           2.9499e-02,  6.8739e-02, -1.1252e-01, -3.1006e-02,  8.4245e-01]],
#        requires_grad=True)
# Teacher training step:  0
# inside epoch before higher optim
# Train student: Step  0 loss value is tensor(-0.4635, grad_fn=<MeanBackward0>)
# Train student: Step  1 loss value is tensor(-0.4633, grad_fn=<MeanBackward0>)
# Train student: Step  2 loss value is tensor(-0.4628, grad_fn=<MeanBackward0>)
# Train student: Step  3 loss value is tensor(-0.4624, grad_fn=<MeanBackward0>)
# Train student: Step  4 loss value is tensor(-0.4614, grad_fn=<MeanBackward0>)
# Train student: Step  5 loss value is tensor(-0.4624, grad_fn=<MeanBackward0>)
# Train student: Step  6 loss value is tensor(-0.4623, grad_fn=<MeanBackward0>)
# Train student: Step  7 loss value is tensor(-0.4609, grad_fn=<MeanBackward0>)
# Train student: Step  8 loss value is tensor(-0.4600, grad_fn=<MeanBackward0>)
# Train student: Step  9 loss value is tensor(-0.4644, grad_fn=<MeanBackward0>)
# Train student: Step  10 loss value is tensor(-0.4590, grad_fn=<MeanBackward0>)
# Train student: Step  11 loss value is tensor(-0.4589, grad_fn=<MeanBackward0>)
# Train student: Step  12 loss value is tensor(-0.4627, grad_fn=<MeanBackward0>)
# Train student: Step  13 loss value is tensor(-0.4611, grad_fn=<MeanBackward0>)
# Train student: Step  14 loss value is tensor(-0.4594, grad_fn=<MeanBackward0>)
# Train student: Step  15 loss value is tensor(-0.4653, grad_fn=<MeanBackward0>)
# Train student: Step  16 loss value is tensor(-0.4565, grad_fn=<MeanBackward0>)
# Train student: Step  17 loss value is tensor(-0.4633, grad_fn=<MeanBackward0>)
# Train student: Step  18 loss value is tensor(-0.4620, grad_fn=<MeanBackward0>)
# Train student: Step  19 loss value is tensor(-0.4655, grad_fn=<MeanBackward0>)
# Train student: Step  20 loss value is tensor(-0.4614, grad_fn=<MeanBackward0>)
# Train student: Step  21 loss value is tensor(-0.4612, grad_fn=<MeanBackward0>)
# Train student: Step  22 loss value is tensor(-0.4605, grad_fn=<MeanBackward0>)
# Train student: Step  99 loss value is tensor(-0.4569, grad_fn=<MeanBackward0>)
# Train student: Step  100 loss value is tensor(-0.4651, grad_fn=<MeanBackward0>)
# Train student: Step  101 loss value is tensor(-0.4640, grad_fn=<MeanBackward0>)
# Train Teacher: Step  0   Teacher loss this step is: tensor(-0.1396, grad_fn=<MulBackward0>)
# Train Teacher: Step  1   Teacher loss this step is: tensor(-0.1477, grad_fn=<MulBackward0>)
# Train Teacher: Step  2   Teacher loss this step is: tensor(-0.1075, grad_fn=<MulBackward0>)
# Train Teacher: Step  3   Teacher loss this step is: tensor(-0.1574, grad_fn=<MulBackward0>)
# Train Teacher: Step  4   Teacher loss this step is: tensor(-0.1163, grad_fn=<MulBackward0>)
# Train Teacher: Step  5   Teacher loss this step is: tensor(-0.1038, grad_fn=<MulBackward0>)
# Train Teacher: Step  6   Teacher loss this step is: tensor(-0.1161, grad_fn=<MulBackward0>)
# Train Teacher: Step  7   Teacher loss this step is: tensor(-0.0972, grad_fn=<MulBackward0>)
# Train Teacher: Step  8   Teacher loss this step is: tensor(-0.0816, grad_fn=<MulBackward0>)
# Train Teacher: Step  9   Teacher loss this step is: tensor(-0.1443, grad_fn=<MulBackward0>)
# Train Teacher: Step  10   Teacher loss this step is: tensor(-0.0820, grad_fn=<MulBackward0>)
# Train Teacher: Step  11   Teacher loss this step is: tensor(-0.1317, grad_fn=<MulBackward0>)
# Train Teacher: Step  12   Teacher loss this step is: tensor(-0.1275, grad_fn=<MulBackward0>)
# Train Teacher: Step  13   Teacher loss this step is: tensor(-0.1022, grad_fn=<MulBackward0>)
# Train Teacher: Step  14   Teacher loss this step is: tensor(-0.0999, grad_fn=<MulBackward0>)
# Train Teacher: Step  15   Teacher loss this step is: tensor(-0.1360, grad_fn=<MulBackward0>)
# Train Teacher: Step  16   Teacher loss this step is: tensor(-0.1359, grad_fn=<MulBackward0>)
# Train Teacher: Step  17   Teacher loss this step is: tensor(-0.1056, grad_fn=<MulBackward0>)
# Train Teacher: Step  18   Teacher loss this step is: tensor(-0.0972, grad_fn=<MulBackward0>)
# Train Teacher: Step  19   Teacher loss this step is: tensor(-0.1236, grad_fn=<MulBackward0>)
# Train Teacher: Step  20   Teacher loss this step is: tensor(-0.1197, grad_fn=<MulBackward0>)
# Train Teacher: Step  21   Teacher loss this step is: tensor(-0.1205, grad_fn=<MulBackward0>)
# Train Teacher: Step  22   Teacher loss this step is: tensor(-0.1040, grad_fn=<MulBackward0>)
# Train Teacher: Step  23   Teacher loss this step is: tensor(-0.1207, grad_fn=<MulBackward0>)
# Train Teacher: Step  24   Teacher loss this step is: tensor(-0.1073, grad_fn=<MulBackward0>)
# Train Teacher: Step  25   Teacher loss this step is: tensor(-0.0907, grad_fn=<MulBackward0>)
# Train Teacher: Step  26   Teacher loss this step is: tensor(-0.1488, grad_fn=<MulBackward0>)
# Train Teacher: Step  27   Teacher loss this step is: tensor(-0.1517, grad_fn=<MulBackward0>)
# Train Teacher: Step  28   Teacher loss this step is: tensor(-0.0945, grad_fn=<MulBackward0>)
# Train Teacher: Step  29   Teacher loss this step is: tensor(-0.1095, grad_fn=<MulBackward0>)
# Train Teacher: Step  30   Teacher loss this step is: tensor(-0.1255, grad_fn=<MulBackward0>)
# Train Teacher: Step  31   Teacher loss this step is: tensor(-0.1253, grad_fn=<MulBackward0>)
# Train Teacher: Step  32   Teacher loss this step is: tensor(-0.1497, grad_fn=<MulBackward0>)
# Train Teacher: Step  33   Teacher loss this step is: tensor(-0.0995, grad_fn=<MulBackward0>)
# Train Teacher: Step  34   Teacher loss this step is: tensor(-0.1310, grad_fn=<MulBackward0>)
# Train Teacher: Step  35   Teacher loss this step is: tensor(-0.0935, grad_fn=<MulBackward0>)
# Train Teacher: Step  36   Teacher loss this step is: tensor(-0.1340, grad_fn=<MulBackward0>)
# Train Teacher: Step  37   Teacher loss this step is: tensor(-0.0998, grad_fn=<MulBackward0>)
# Train Teacher: Step  38   Teacher loss this step is: tensor(-0.0912, grad_fn=<MulBackward0>)
# Train Teacher: Step  39   Teacher loss this step is: tensor(-0.0930, grad_fn=<MulBackward0>)
# Train Teacher: Step  40   Teacher loss this step is: tensor(-0.0948, grad_fn=<MulBackward0>)
# Train Teacher: Step  41   Teacher loss this step is: tensor(-0.1054, grad_fn=<MulBackward0>)
# Train Teacher: Step  42   Teacher loss this step is: tensor(-0.1007, grad_fn=<MulBackward0>)
# Train Teacher: Step  43   Teacher loss this step is: tensor(-0.1058, grad_fn=<MulBackward0>)
# Train Teacher: Step  44   Teacher loss this step is: tensor(-0.1019, grad_fn=<MulBackward0>)
# Train Teacher: Step  45   Teacher loss this step is: tensor(-0.1006, grad_fn=<MulBackward0>)
# Train Teacher: Step  46   Teacher loss this step is: tensor(-0.1008, grad_fn=<MulBackward0>)
# Train Teacher: Step  47   Teacher loss this step is: tensor(-0.1091, grad_fn=<MulBackward0>)
# Train Teacher: Step  48   Teacher loss this step is: tensor(-0.1178, grad_fn=<MulBackward0>)
# Train Teacher: Step  49   Teacher loss this step is: tensor(-0.0843, grad_fn=<MulBackward0>)
# Train Teacher: Step  50   Teacher loss this step is: tensor(-0.0953, grad_fn=<MulBackward0>)
# Train Teacher: Step  51   Teacher loss this step is: tensor(-0.1445, grad_fn=<MulBackward0>)
# phi mean grad tensor(0.0083) V max grad tensor(0.0224)
# student conv1 mean grad tensor(0.0040) student conv1 max grad tensor(0.0159)
# test
# Parameter containing:
# tensor([[ 0.7655,  0.0167,  0.0034, -0.0978,  0.0414, -0.0417,  0.0956, -0.0789,
#          -0.0499, -0.1343],
#         [-0.0222,  1.0032, -0.0945, -0.1233, -0.1081, -0.1515,  0.0237, -0.0057,
#          -0.0740,  0.0263],
#         [-0.0574,  0.0899,  0.9829, -0.0829, -0.0572, -0.0708, -0.1254, -0.1264,
#           0.2027, -0.1300],
#         [-0.0745,  0.0566,  0.0109,  0.7049,  0.1116,  0.1446, -0.0208,  0.2119,
#           0.1164,  0.0207],
#         [ 0.0258, -0.0909,  0.0819, -0.0940,  1.1400,  0.0114,  0.1781, -0.0970,
#          -0.0047,  0.1604],
#         [ 0.1299, -0.0262,  0.1274,  0.1987, -0.0410,  1.0627,  0.0558,  0.1809,
#          -0.3099,  0.1045],
#         [ 0.1747,  0.0947, -0.0115,  0.1778,  0.0544,  0.2264,  0.9161,  0.0039,
#          -0.0794, -0.0476],
#         [-0.0810,  0.0899,  0.1231, -0.0565,  0.0759, -0.0716, -0.0540,  0.9261,
#          -0.2069, -0.0349],
#         [ 0.1196, -0.0287, -0.0247,  0.0346,  0.0285,  0.0219,  0.1165,  0.0717,
#           0.9657, -0.0790],
#         [-0.1678, -0.0593,  0.0021, -0.0156,  0.1357,  0.0209,  0.0687, -0.1025,
#          -0.0210,  0.8351]], requires_grad=True)
# Teacher training step:  1
# inside epoch before higher optim
# Train student: Step  0 loss value is tensor(-0.4522, grad_fn=<MeanBackward0>)
# Train student: Step  1 loss value is tensor(-0.4645, grad_fn=<MeanBackward0>)
# Train student: Step  2 loss value is tensor(-0.4641, grad_fn=<MeanBackward0>)
# Train student: Step  3 loss value is tensor(-0.4608, grad_fn=<MeanBackward0>)
# Train student: Step  4 loss value is tensor(-0.4569, grad_fn=<MeanBackward0>)
# Train student: Step  5 loss value is tensor(-0.4564, grad_fn=<MeanBackward0>)
# Train student: Step  6 loss value is tensor(-0.4551, grad_fn=<MeanBackward0>)
# Train student: Step  7 loss value is tensor(-0.4594, grad_fn=<MeanBackward0>)
# Train student: Step  8 loss value is tensor(-0.4574, grad_fn=<MeanBackward0>)
# Train student: Step  9 loss value is tensor(-0.4601, grad_fn=<MeanBackward0>)
# Train student: Step  10 loss value is tensor(-0.4611, grad_fn=<MeanBackward0>)
# Train student: Step  11 loss value is tensor(-0.4628, grad_fn=<MeanBackward0>)
# Train student: Step  12 loss value is tensor(-0.4641, grad_fn=<MeanBackward0>)
# Train student: Step  13 loss value is tensor(-0.4603, grad_fn=<MeanBackward0>)
# Train student: Step  14 loss value is tensor(-0.4602, grad_fn=<MeanBackward0>)
# Train student: Step  15 loss value is tensor(-0.4554, grad_fn=<MeanBackward0>)
# Train student: Step  16 loss value is tensor(-0.4533, grad_fn=<MeanBackward0>)
# Train student: Step  17 loss value is tensor(-0.4636, grad_fn=<MeanBackward0>)
# Train student: Step  18 loss value is tensor(-0.4532, grad_fn=<MeanBackward0>)
# Train student: Step  19 loss value is tensor(-0.4575, grad_fn=<MeanBackward0>)
# Train student: Step  20 loss value is tensor(-0.4607, grad_fn=<MeanBackward0>)
# Train student: Step  21 loss value is tensor(-0.4543, grad_fn=<MeanBackward0>)
# Train student: Step  22 loss value is tensor(-0.4608, grad_fn=<MeanBackward0>)
# Train student: Step  23 loss value is tensor(-0.4621, grad_fn=<MeanBackward0>)
# Train student: Step  24 loss value is tensor(-0.4609, grad_fn=<MeanBackward0>)
# Train student: Step  25 loss value is tensor(-0.4631, grad_fn=<MeanBackward0>)
# Train student: Step  26 loss value is tensor(-0.4579, grad_fn=<MeanBackward0>)
# Train student: Step  27 loss value is tensor(-0.4581, grad_fn=<MeanBackward0>)
# Train student: Step  28 loss value is tensor(-0.4542, grad_fn=<MeanBackward0>)
# Train Teacher: Step  2   Teacher loss this step is: tensor(-0.1250, grad_fn=<MulBackward0>)
# Train Teacher: Step  3   Teacher loss this step is: tensor(-0.1152, grad_fn=<MulBackward0>)
# Train Teacher: Step  4   Teacher loss this step is: tensor(-0.1355, grad_fn=<MulBackward0>)
# Train Teacher: Step  5   Teacher loss this step is: tensor(-0.0979, grad_fn=<MulBackward0>)
# Train Teacher: Step  6   Teacher loss this step is: tensor(-0.1071, grad_fn=<MulBackward0>)
# Train Teacher: Step  7   Teacher loss this step is: tensor(-0.1287, grad_fn=<MulBackward0>)
# Train Teacher: Step  8   Teacher loss this step is: tensor(-0.1239, grad_fn=<MulBackward0>)
# Train Teacher: Step  9   Teacher loss this step is: tensor(-0.1143, grad_fn=<MulBackward0>)
# Train Teacher: Step  10   Teacher loss this step is: tensor(-0.1209, grad_fn=<MulBackward0>)
# Train Teacher: Step  11   Teacher loss this step is: tensor(-0.1312, grad_fn=<MulBackward0>)
# Train Teacher: Step  12   Teacher loss this step is: tensor(-0.1146, grad_fn=<MulBackward0>)
# Train Teacher: Step  13   Teacher loss this step is: tensor(-0.1126, grad_fn=<MulBackward0>)
# Train Teacher: Step  14   Teacher loss this step is: tensor(-0.1099, grad_fn=<MulBackward0>)
# Train Teacher: Step  15   Teacher loss this step is: tensor(-0.1070, grad_fn=<MulBackward0>)
# Train Teacher: Step  16   Teacher loss this step is: tensor(-0.1060, grad_fn=<MulBackward0>)
# Train Teacher: Step  17   Teacher loss this step is: tensor(-0.1176, grad_fn=<MulBackward0>)
# Train Teacher: Step  18   Teacher loss this step is: tensor(-0.1078, grad_fn=<MulBackward0>)
# Train Teacher: Step  19   Teacher loss this step is: tensor(-0.1372, grad_fn=<MulBackward0>)
# Train Teacher: Step  20   Teacher loss this step is: tensor(-0.1129, grad_fn=<MulBackward0>)
# Train Teacher: Step  21   Teacher loss this step is: tensor(-0.1358, grad_fn=<MulBackward0>)
# Train Teacher: Step  22   Teacher loss this step is: tensor(-0.1231, grad_fn=<MulBackward0>)
# Train Teacher: Step  23   Teacher loss this step is: tensor(-0.1244, grad_fn=<MulBackward0>)
# Train Teacher: Step  24   Teacher loss this step is: tensor(-0.1245, grad_fn=<MulBackward0>)
# Train Teacher: Step  25   Teacher loss this step is: tensor(-0.1189, grad_fn=<MulBackward0>)
# Train Teacher: Step  26   Teacher loss this step is: tensor(-0.1107, grad_fn=<MulBackward0>)
# Train Teacher: Step  27   Teacher loss this step is: tensor(-0.1219, grad_fn=<MulBackward0>)
# Train Teacher: Step  28   Teacher loss this step is: tensor(-0.1104, grad_fn=<MulBackward0>)
# Train Teacher: Step  29   Teacher loss this step is: tensor(-0.1289, grad_fn=<MulBackward0>)
# Train Teacher: Step  30   Teacher loss this step is: tensor(-0.1226, grad_fn=<MulBackward0>)
# Train Teacher: Step  31   Teacher loss this step is: tensor(-0.1197, grad_fn=<MulBackward0>)
# Train Teacher: Step  32   Teacher loss this step is: tensor(-0.1233, grad_fn=<MulBackward0>)
# Train Teacher: Step  33   Teacher loss this step is: tensor(-0.1103, grad_fn=<MulBackward0>)
# Train Teacher: Step  34   Teacher loss this step is: tensor(-0.1141, grad_fn=<MulBackward0>)
# Train Teacher: Step  35   Teacher loss this step is: tensor(-0.1120, grad_fn=<MulBackward0>)
# Train Teacher: Step  36   Teacher loss this step is: tensor(-0.1211, grad_fn=<MulBackward0>)
# Train Teacher: Step  37   Teacher loss this step is: tensor(-0.1465, grad_fn=<MulBackward0>)
# Train Teacher: Step  38   Teacher loss this step is: tensor(-0.1372, grad_fn=<MulBackward0>)
# Train Teacher: Step  39   Teacher loss this step is: tensor(-0.1132, grad_fn=<MulBackward0>)
# Train Teacher: Step  40   Teacher loss this step is: tensor(-0.1170, grad_fn=<MulBackward0>)
# Train Teacher: Step  41   Teacher loss this step is: tensor(-0.1375, grad_fn=<MulBackward0>)
# Train Teacher: Step  42   Teacher loss this step is: tensor(-0.1489, grad_fn=<MulBackward0>)
# Train Teacher: Step  43   Teacher loss this step is: tensor(-0.1110, grad_fn=<MulBackward0>)
# Train Teacher: Step  44   Teacher loss this step is: tensor(-0.1163, grad_fn=<MulBackward0>)
# Train Teacher: Step  45   Teacher loss this step is: tensor(-0.1264, grad_fn=<MulBackward0>)
# Train Teacher: Step  46   Teacher loss this step is: tensor(-0.1304, grad_fn=<MulBackward0>)
# Train Teacher: Step  47   Teacher loss this step is: tensor(-0.1321, grad_fn=<MulBackward0>)
# Train Teacher: Step  48   Teacher loss this step is: tensor(-0.1307, grad_fn=<MulBackward0>)
# Train Teacher: Step  49   Teacher loss this step is: tensor(-0.1307, grad_fn=<MulBackward0>)
# Train Teacher: Step  50   Teacher loss this step is: tensor(-0.1052, grad_fn=<MulBackward0>)
# Train Teacher: Step  51   Teacher loss this step is: tensor(-0.1225, grad_fn=<MulBackward0>)
# phi mean grad tensor(0.0033) V max grad tensor(0.0145)
# student conv1 mean grad tensor(0.0064) student conv1 max grad tensor(0.0263)
# test
# Parameter containing:
# tensor([[ 0.7619,  0.0186,  0.0079, -0.0885,  0.0315, -0.0484,  0.0939, -0.0693,
#          -0.0424, -0.1277],
#         [-0.0183,  0.9945, -0.0864, -0.1157, -0.1171, -0.1573,  0.0204, -0.0050,
#          -0.0657,  0.0348],
#         [-0.0478,  0.0969,  0.9755, -0.0747, -0.0667, -0.0778, -0.1262, -0.1174,
#           0.2094, -0.1241],
#         [-0.0650,  0.0640,  0.0187,  0.6973,  0.1022,  0.1370, -0.0221,  0.2211,
#           0.1232,  0.0278],
#         [ 0.0345, -0.0838,  0.0877, -0.0896,  1.1465,  0.0038,  0.1769, -0.0870,
#           0.0036,  0.1647],
#         [ 0.1394, -0.0184,  0.1330,  0.2063, -0.0505,  1.0711,  0.0541,  0.1904,
#          -0.3008,  0.1121],
#         [ 0.1841,  0.1021, -0.0040,  0.1827,  0.0451,  0.2185,  0.9141,  0.0067,
#          -0.0711, -0.0413],
#         [-0.0716,  0.0969,  0.1283, -0.0502,  0.0666, -0.0785, -0.0573,  0.9164,
#          -0.1984, -0.0274],
#         [ 0.1281, -0.0203, -0.0167,  0.0415,  0.0193,  0.0154,  0.1152,  0.0789,
#           0.9587, -0.0707],
#         [-0.1586, -0.0527,  0.0082, -0.0098,  0.1268,  0.0133,  0.0658, -0.0925,
#          -0.0135,  0.8310]], requires_grad=True)
# Teacher training step:  2
# inside epoch before higher optim
# Train student: Step  0 loss value is tensor(-0.4519, grad_fn=<MeanBackward0>)
# Train student: Step  1 loss value is tensor(-0.4581, grad_fn=<MeanBackward0>)
# Train student: Step  2 loss value is tensor(-0.4569, grad_fn=<MeanBackward0>)
# Train student: Step  3 loss value is tensor(-0.4575, grad_fn=<MeanBackward0>)
# Train student: Step  4 loss value is tensor(-0.4569, grad_fn=<MeanBackward0>)
# Train student: Step  5 loss value is tensor(-0.4610, grad_fn=<MeanBackward0>)
# Train student: Step  6 loss value is tensor(-0.4555, grad_fn=<MeanBackward0>)
# Train student: Step  7 loss value is tensor(-0.4548, grad_fn=<MeanBackward0>)
# Train student: Step  8 loss value is tensor(-0.4532, grad_fn=<MeanBackward0>)
# Train student: Step  9 loss value is tensor(-0.4634, grad_fn=<MeanBackward0>)
# Train student: Step  10 loss value is tensor(-0.4561, grad_fn=<MeanBackward0>)
# Train student: Step  11 loss value is tensor(-0.4567, grad_fn=<MeanBackward0>)
# Train student: Step  12 loss value is tensor(-0.4597, grad_fn=<MeanBackward0>)
# Train student: Step  13 loss value is tensor(-0.4602, grad_fn=<MeanBackward0>)
# Train student: Step  14 loss value is tensor(-0.4585, grad_fn=<MeanBackward0>)
# Train student: Step  15 loss value is tensor(-0.4558, grad_fn=<MeanBackward0>)
# Train student: Step  16 loss value is tensor(-0.4546, grad_fn=<MeanBackward0>)
# Train student: Step  17 loss value is tensor(-0.4556, grad_fn=<MeanBackward0>)
# Train student: Step  18 loss value is tensor(-0.4549, grad_fn=<MeanBackward0>)
# Train student: Step  19 loss value is tensor(-0.4566, grad_fn=<MeanBackward0>)
# Train student: Step  20 loss value is tensor(-0.4565, grad_fn=<MeanBackward0>)
# Train student: Step  21 loss value is tensor(-0.4562, grad_fn=<MeanBackward0>)
# Train student: Step  22 loss value is tensor(-0.4561, grad_fn=<MeanBackward0>)
# Train student: Step  23 loss value is tensor(-0.4615, grad_fn=<MeanBackward0>)
# Train student: Step  24 loss value is tensor(-0.4563, grad_fn=<MeanBackward0>)
# Train student: Step  25 loss value is tensor(-0.4523, grad_fn=<MeanBackward0>)
# Train student: Step  26 loss value is tensor(-0.4560, grad_fn=<MeanBackward0>)
# Train student: Step  27 loss value is tensor(-0.4610, grad_fn=<MeanBackward0>)
# Train student: Step  28 loss value is tensor(-0.4587, grad_fn=<MeanBackward0>)
# Train student: Step  29 loss value is tensor(-0.4542, grad_fn=<MeanBackward0>)
# Train student: Step  30 loss value is tensor(-0.4612, grad_fn=<MeanBackward0>)
# Train student: Step  31 loss value is tensor(-0.4602, grad_fn=<MeanBackward0>)
# Train student: Step  32 loss value is tensor(-0.4547, grad_fn=<MeanBackward0>)
# Train student: Step  33 loss value is tensor(-0.4553, grad_fn=<MeanBackward0>)
# Train student: Step  34 loss value is tensor(-0.4525, grad_fn=<MeanBackward0>)
# Train student: Step  35 loss value is tensor(-0.4612, grad_fn=<MeanBackward0>)
# Train student: Step  36 loss value is tensor(-0.4535, grad_fn=<MeanBackward0>)
# Train student: Step  37 loss value is tensor(-0.4609, grad_fn=<MeanBackward0>)
# Train student: Step  38 loss value is tensor(-0.4629, grad_fn=<MeanBackward0>)
# Train student: Step  39 loss value is tensor(-0.4600, grad_fn=<MeanBackward0>)
# Train student: Step  40 loss value is tensor(-0.4606, grad_fn=<MeanBackward0>)
# Train student: Step  41 loss value is tensor(-0.4623, grad_fn=<MeanBackward0>)
# Train student: Step  42 loss value is tensor(-0.4578, grad_fn=<MeanBackward0>)
# Train student: Step  43 loss value is tensor(-0.4560, grad_fn=<MeanBackward0>)
# Train student: Step  44 loss value is tensor(-0.4600, grad_fn=<MeanBackward0>)
# Train student: Step  45 loss value is tensor(-0.4619, grad_fn=<MeanBackward0>)
# Train student: Step  46 loss value is tensor(-0.4568, grad_fn=<MeanBackward0>)
# Train student: Step  47 loss value is tensor(-0.4590, grad_fn=<MeanBackward0>)
# Train student: Step  48 loss value is tensor(-0.4565, grad_fn=<MeanBackward0>)
# Train student: Step  49 loss value is tensor(-0.4600, grad_fn=<MeanBackward0>)
# Train student: Step  50 loss value is tensor(-0.4576, grad_fn=<MeanBackward0>)
# Train student: Step  51 loss value is tensor(-0.4568, grad_fn=<MeanBackward0>)
# Train student: Step  52 loss value is tensor(-0.4586, grad_fn=<MeanBackward0>)
# Train student: Step  53 loss value is tensor(-0.4570, grad_fn=<MeanBackward0>)
# Train student: Step  54 loss value is tensor(-0.4659, grad_fn=<MeanBackward0>)
# Train student: Step  55 loss value is tensor(-0.4610, grad_fn=<MeanBackward0>)
# Train student: Step  56 loss value is tensor(-0.4558, grad_fn=<MeanBackward0>)
# Train student: Step  57 loss value is tensor(-0.4580, grad_fn=<MeanBackward0>)
# Train student: Step  58 loss value is tensor(-0.4599, grad_fn=<MeanBackward0>)
# Train student: Step  59 loss value is tensor(-0.4584, grad_fn=<MeanBackward0>)
# Train student: Step  60 loss value is tensor(-0.4593, grad_fn=<MeanBackward0>)
# Train student: Step  61 loss value is tensor(-0.4552, grad_fn=<MeanBackward0>)
# ...
#           9.5039e-02,  8.6322e-02,  8.4772e-02,  8.2730e-02,  9.5264e-02],
#         [-5.7077e-02, -1.3049e-04, -2.2878e-03,  2.9630e-02,  1.8274e+00,
#          -2.3829e-02,  3.8807e-03,  1.7224e-01,  2.5685e-02, -1.5641e-03],
#         [ 3.3020e-01,  6.0466e-02,  4.0555e-02,  6.7413e-02,  3.8279e-02,
#           1.7144e+00,  7.2054e-02, -2.4765e-02,  8.7426e-02,  8.3244e-02],
#         [ 2.9808e-01,  4.4416e-02,  3.6157e-02,  4.3600e-02,  2.9483e-02,
#           7.5321e-02,  1.7611e+00, -1.2981e-01,  6.0831e-02,  4.0928e-02],
#         [-2.3223e-01, -9.7824e-02, -1.2890e-01, -1.3547e-01, -1.1221e-01,
#          -7.8247e-02, -5.0843e-02,  1.1144e+00, -8.8604e-02, -1.1475e-01],
#         [-1.8093e-02,  2.6836e-01,  5.0701e-02,  3.6858e-02,  4.2045e-02,
#           6.8976e-02,  4.0149e-02,  5.8561e-02,  1.7108e+00,  3.4719e-02],
#         [-1.4281e-01, -2.8636e-02,  1.2988e-02, -3.0727e-02, -5.3759e-03,
#          -2.4713e-02,  9.1904e-03,  2.6665e-01, -3.9396e-02,  1.6541e+00]],
#        requires_grad=True)
# Teacher training step:  174
# inside epoch before higher optim
# Train student: Step  0 loss value is tensor(-0.4688, grad_fn=<MeanBackward0>)
# Train student: Step  1 loss value is tensor(-0.4630, grad_fn=<MeanBackward0>)
# Train student: Step  2 loss value is tensor(-0.4734, grad_fn=<MeanBackward0>)
# Train student: Step  3 loss value is tensor(-0.4635, grad_fn=<MeanBackward0>)
# Train student: Step  4 loss value is tensor(-0.4526, grad_fn=<MeanBackward0>)
# Train student: Step  5 loss value is tensor(-0.4586, grad_fn=<MeanBackward0>)
# Train student: Step  6 loss value is tensor(-0.4647, grad_fn=<MeanBackward0>)
# Train student: Step  7 loss value is tensor(-0.4657, grad_fn=<MeanBackward0>)
# Train student: Step  8 loss value is tensor(-0.4676, grad_fn=<MeanBackward0>)
# Train student: Step  9 loss value is tensor(-0.4615, grad_fn=<MeanBackward0>)
# Train student: Step  10 loss value is tensor(-0.4641, grad_fn=<MeanBackward0>)
# Train student: Step  11 loss value is tensor(-0.4791, grad_fn=<MeanBackward0>)
# Train student: Step  12 loss value is tensor(-0.4736, grad_fn=<MeanBackward0>)
# Train student: Step  13 loss value is tensor(-0.4595, grad_fn=<MeanBackward0>)
# Train student: Step  14 loss value is tensor(-0.4645, grad_fn=<MeanBackward0>)
# Train student: Step  15 loss value is tensor(-0.4735, grad_fn=<MeanBackward0>)
# Train student: Step  16 loss value is tensor(-0.4663, grad_fn=<MeanBackward0>)
# Train student: Step  17 loss value is tensor(-0.4730, grad_fn=<MeanBackward0>)
# Train student: Step  18 loss value is tensor(-0.4549, grad_fn=<MeanBackward0>)
# Train student: Step  19 loss value is tensor(-0.4689, grad_fn=<MeanBackward0>)
# Train student: Step  20 loss value is tensor(-0.4805, grad_fn=<MeanBackward0>)
# Train student: Step  21 loss value is tensor(-0.4672, grad_fn=<MeanBackward0>)
# Train student: Step  22 loss value is tensor(-0.4596, grad_fn=<MeanBackward0>)
# Train student: Step  23 loss value is tensor(-0.4518, grad_fn=<MeanBackward0>)
# Train student: Step  24 loss value is tensor(-0.4795, grad_fn=<MeanBackward0>)
# Train student: Step  25 loss value is tensor(-0.4729, grad_fn=<MeanBackward0>)
# Train student: Step  26 loss value is tensor(-0.4851, grad_fn=<MeanBackward0>)
# Train student: Step  27 loss value is tensor(-0.4569, grad_fn=<MeanBackward0>)
# Train student: Step  28 loss value is tensor(-0.4595, grad_fn=<MeanBackward0>)
# Train student: Step  29 loss value is tensor(-0.4700, grad_fn=<MeanBackward0>)
# Train student: Step  30 loss value is tensor(-0.4532, grad_fn=<MeanBackward0>)
# Train student: Step  31 loss value is tensor(-0.4572, grad_fn=<MeanBackward0>)
# Train student: Step  70 loss value is tensor(-0.4859, grad_fn=<MeanBackward0>)
# Train student: Step  71 loss value is tensor(-0.4673, grad_fn=<MeanBackward0>)
# Train student: Step  72 loss value is tensor(-0.4767, grad_fn=<MeanBackward0>)
# Train student: Step  73 loss value is tensor(-0.4673, grad_fn=<MeanBackward0>)
# Train student: Step  74 loss value is tensor(-0.4614, grad_fn=<MeanBackward0>)
# Train student: Step  75 loss value is tensor(-0.4808, grad_fn=<MeanBackward0>)
# Train student: Step  76 loss value is tensor(-0.4694, grad_fn=<MeanBackward0>)
# Train student: Step  77 loss value is tensor(-0.4838, grad_fn=<MeanBackward0>)
# Train student: Step  78 loss value is tensor(-0.4695, grad_fn=<MeanBackward0>)
# Train student: Step  79 loss value is tensor(-0.4699, grad_fn=<MeanBackward0>)
# Train student: Step  80 loss value is tensor(-0.4678, grad_fn=<MeanBackward0>)
# Train student: Step  81 loss value is tensor(-0.4746, grad_fn=<MeanBackward0>)
# Train student: Step  82 loss value is tensor(-0.4823, grad_fn=<MeanBackward0>)
# Train student: Step  83 loss value is tensor(-0.4806, grad_fn=<MeanBackward0>)
# Train student: Step  84 loss value is tensor(-0.4773, grad_fn=<MeanBackward0>)
# Train student: Step  85 loss value is tensor(-0.4879, grad_fn=<MeanBackward0>)
# Train student: Step  86 loss value is tensor(-0.4660, grad_fn=<MeanBackward0>)
# Train student: Step  87 loss value is tensor(-0.4506, grad_fn=<MeanBackward0>)
# Train student: Step  88 loss value is tensor(-0.4720, grad_fn=<MeanBackward0>)
# Train student: Step  89 loss value is tensor(-0.4862, grad_fn=<MeanBackward0>)
# Train student: Step  90 loss value is tensor(-0.4848, grad_fn=<MeanBackward0>)
# Train student: Step  91 loss value is tensor(-0.4693, grad_fn=<MeanBackward0>)
# Train student: Step  92 loss value is tensor(-0.4786, grad_fn=<MeanBackward0>)
# Train student: Step  93 loss value is tensor(-0.4859, grad_fn=<MeanBackward0>)
# Train student: Step  94 loss value is tensor(-0.4824, grad_fn=<MeanBackward0>)
# Train student: Step  95 loss value is tensor(-0.4784, grad_fn=<MeanBackward0>)
# Train student: Step  96 loss value is tensor(-0.5033, grad_fn=<MeanBackward0>)
# Train student: Step  97 loss value is tensor(-0.4769, grad_fn=<MeanBackward0>)
# Train student: Step  98 loss value is tensor(-0.4777, grad_fn=<MeanBackward0>)
# Train student: Step  99 loss value is tensor(-0.4758, grad_fn=<MeanBackward0>)
# Train student: Step  100 loss value is tensor(-0.4834, grad_fn=<MeanBackward0>)
# Train student: Step  101 loss value is tensor(-0.4944, grad_fn=<MeanBackward0>)
# Train Teacher: Step  0   Teacher loss this step is: tensor(-0.0936, grad_fn=<MulBackward0>)
# Train Teacher: Step  1   Teacher loss this step is: tensor(-0.1783, grad_fn=<MulBackward0>)
# Train Teacher: Step  2   Teacher loss this step is: tensor(-0.1612, grad_fn=<MulBackward0>)
# Train Teacher: Step  3   Teacher loss this step is: tensor(-0.2301, grad_fn=<MulBackward0>)
# Train Teacher: Step  4   Teacher loss this step is: tensor(-0.1622, grad_fn=<MulBackward0>)
# Train Teacher: Step  5   Teacher loss this step is: tensor(-0.1920, grad_fn=<MulBackward0>)
# Train Teacher: Step  6   Teacher loss this step is: tensor(-0.0978, grad_fn=<MulBackward0>)
# Train Teacher: Step  7   Teacher loss this step is: tensor(-0.1560, grad_fn=<MulBackward0>)
# Train Teacher: Step  8   Teacher loss this step is: tensor(-0.2067, grad_fn=<MulBackward0>)
# Train Teacher: Step  9   Teacher loss this step is: tensor(-0.1527, grad_fn=<MulBackward0>)
# Train Teacher: Step  10   Teacher loss this step is: tensor(-0.1198, grad_fn=<MulBackward0>)
# Train Teacher: Step  11   Teacher loss this step is: tensor(-0.2104, grad_fn=<MulBackward0>)
# Train Teacher: Step  12   Teacher loss this step is: tensor(-0.1412, grad_fn=<MulBackward0>)
# Train Teacher: Step  13   Teacher loss this step is: tensor(-0.1904, grad_fn=<MulBackward0>)
# Train Teacher: Step  14   Teacher loss this step is: tensor(-0.1745, grad_fn=<MulBackward0>)
# Train Teacher: Step  15   Teacher loss this step is: tensor(-0.1560, grad_fn=<MulBackward0>)
# Train Teacher: Step  16   Teacher loss this step is: tensor(-0.1340, grad_fn=<MulBackward0>)
# Train Teacher: Step  17   Teacher loss this step is: tensor(-0.1286, grad_fn=<MulBackward0>)
# Train Teacher: Step  18   Teacher loss this step is: tensor(-0.1967, grad_fn=<MulBackward0>)
# Train Teacher: Step  19   Teacher loss this step is: tensor(-0.2347, grad_fn=<MulBackward0>)
# Train Teacher: Step  20   Teacher loss this step is: tensor(-0.1784, grad_fn=<MulBackward0>)
# Train Teacher: Step  21   Teacher loss this step is: tensor(-0.1272, grad_fn=<MulBackward0>)
# Train Teacher: Step  22   Teacher loss this step is: tensor(-0.1315, grad_fn=<MulBackward0>)
# Train Teacher: Step  23   Teacher loss this step is: tensor(-0.1235, grad_fn=<MulBackward0>)
# Train Teacher: Step  24   Teacher loss this step is: tensor(-0.1514, grad_fn=<MulBackward0>)
# Train Teacher: Step  25   Teacher loss this step is: tensor(-0.1005, grad_fn=<MulBackward0>)
# Train Teacher: Step  26   Teacher loss this step is: tensor(-0.1382, grad_fn=<MulBackward0>)
# Train Teacher: Step  27   Teacher loss this step is: tensor(-0.1617, grad_fn=<MulBackward0>)
# Train Teacher: Step  28   Teacher loss this step is: tensor(-0.1991, grad_fn=<MulBackward0>)
# Train Teacher: Step  29   Teacher loss this step is: tensor(-0.2019, grad_fn=<MulBackward0>)
# Train Teacher: Step  30   Teacher loss this step is: tensor(-0.1883, grad_fn=<MulBackward0>)
# Train Teacher: Step  31   Teacher loss this step is: tensor(-0.1658, grad_fn=<MulBackward0>)
# Train Teacher: Step  32   Teacher loss this step is: tensor(-0.1640, grad_fn=<MulBackward0>)
# Train Teacher: Step  33   Teacher loss this step is: tensor(-0.2127, grad_fn=<MulBackward0>)
# Train Teacher: Step  34   Teacher loss this step is: tensor(-0.1557, grad_fn=<MulBackward0>)
# Train Teacher: Step  35   Teacher loss this step is: tensor(-0.1727, grad_fn=<MulBackward0>)
# Train Teacher: Step  36   Teacher loss this step is: tensor(-0.1678, grad_fn=<MulBackward0>)
# Train Teacher: Step  37   Teacher loss this step is: tensor(-0.1834, grad_fn=<MulBackward0>)
# Train Teacher: Step  38   Teacher loss this step is: tensor(-0.1726, grad_fn=<MulBackward0>)
# Train Teacher: Step  39   Teacher loss this step is: tensor(-0.1413, grad_fn=<MulBackward0>)
# Train Teacher: Step  40   Teacher loss this step is: tensor(-0.2256, grad_fn=<MulBackward0>)
# Train Teacher: Step  41   Teacher loss this step is: tensor(-0.1656, grad_fn=<MulBackward0>)
# Train Teacher: Step  42   Teacher loss this step is: tensor(-0.1288, grad_fn=<MulBackward0>)
# Train Teacher: Step  43   Teacher loss this step is: tensor(-0.1525, grad_fn=<MulBackward0>)
# Train Teacher: Step  44   Teacher loss this step is: tensor(-0.1412, grad_fn=<MulBackward0>)
# Train Teacher: Step  45   Teacher loss this step is: tensor(-0.1282, grad_fn=<MulBackward0>)
# Train Teacher: Step  46   Teacher loss this step is: tensor(-0.1279, grad_fn=<MulBackward0>)
# Train Teacher: Step  47   Teacher loss this step is: tensor(-0.1504, grad_fn=<MulBackward0>)
# Train Teacher: Step  48   Teacher loss this step is: tensor(-0.1559, grad_fn=<MulBackward0>)
# Train Teacher: Step  49   Teacher loss this step is: tensor(-0.1620, grad_fn=<MulBackward0>)
# Train Teacher: Step  50   Teacher loss this step is: tensor(-0.1773, grad_fn=<MulBackward0>)
# Train Teacher: Step  51   Teacher loss this step is: tensor(-0.1932, grad_fn=<MulBackward0>)
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /var/folders/43/5971cqb109bfv3wb3b47x9tc0000gn/T/ipykernel_21445/2160689624.py in <module>
# ----> 1 teacher, student = train(train_loader, val_loader, test_loader, num_steps=1000)
#
# /var/folders/43/5971cqb109bfv3wb3b47x9tc0000gn/T/ipykernel_21445/1351321284.py in train(train_dl, val_dl, test_dl, num_steps)
#      18             # Note: do_train_student does not edit the .grad field of teacher parameters
#      19             # Therefore, no need to clear teacher grads before do_train_teacher.
# ---> 20             teacher_ld, teacher = do_train_teacher(teacher, teacher_optim, fnet, val_dl)
#      21             student.load_state_dict(fnet.state_dict())
#      22             # print( "V mean grad", torch.mean(torch.abs(teacher.V.grad)), "V max grad", torch.max(torch.abs(teacher.V.grad)) )
#
# /var/folders/43/5971cqb109bfv3wb3b47x9tc0000gn/T/ipykernel_21445/2201675568.py in do_train_teacher(teacher, optimizer, student, train_dl)
#      25     # Accumulate losses and do the step after we process outer_steps number of batches.
#      26     netloss = netloss/(i+1)
# ---> 27     netloss.backward(retain_graph=True)
#      28     return lossdict, teacher
#
# ~/miniconda3/envs/commentaries/lib/python3.7/site-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#     183                 products. Defaults to ``False``.
#     184         """
# --> 185         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     186
#     187     def register_hook(self, hook):
#
# ~/miniconda3/envs/commentaries/lib/python3.7/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#     125     Variable._execution_engine.run_backward(
#     126         tensors, grad_tensors, retain_graph, create_graph,
# --> 127         allow_unreachable=True)  # allow_unreachable flag
#     128
#     129
#
# RuntimeError: python_error

# %%
print(teacher.phi)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/43/5971cqb109bfv3wb3b47x9tc0000gn/T/ipykernel_20373/2154237865.py in <module>
# ----> 1 print(teacher.phi)
#
# NameError: name 'teacher' is not defined
